# %%
import pandas as pd

data = pd.read_csv('./data.csv')
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
fig, ax = plt.subplots(figsize=(20,20))
sns.heatmap(sample.corr(), annot=True, linewidth=.5, fmt='.1f', ax=ax)

# %%
keeps = [
    'area_mean', 'area_se', 'area_worst', 'texture_mean'
    'concavity_mean', 'concavity_se', 'concavity_worst',
]

drops = [item for item in sample.columns.tolist() if item not in keeps]

sample_1 = sample.drop(drops, axis=1)
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(sample_1.corr(), annot=True, linewidth=.5, fmt='.1f', ax=ax)

plt.show()

# %%
sample_n_1 = (sample_1 - sample_1.mean()) / sample_1.std()
data = pd.concat([labels, sample_n_1], axis=1)
data = pd.melt(data, id_vars='diagnosis', var_name='features', value_name='value')
plt.figure(figsize=(10,10))
sns.swarmplot(x="features", y="value", hue="diagnosis", data=data)

plt.show()

keeps = [
    'area_mean', 'concave points_mean',
    'perimeter_worst', 'area_worst',
    'area_se', 'perimeter_se'
]
